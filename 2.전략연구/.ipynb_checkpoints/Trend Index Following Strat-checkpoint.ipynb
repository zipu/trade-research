# %%
# %matplotlib inline
import sys
sys.path.append('..')
from modules.backtesting import BackTesting
import pandas as pd
from keras.models import load_model
from modules.factory import norm, fmeasure, recall
import h5py
pd.options.display.float_format = '{:,.2f}'.format #화면에 소숫점 2번째 자리까지만 표시
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 0. Parameters

# %%
predic_model_file= '../data/keras models/uptrend-predic(20-240-40).h5'
raw_data_file = '../data/training set/40day_trend_labeled_futures.h5'

# %%
predic_model = load_model(predic_model_file, custom_objects={'recall':recall, 'fmeasure':fmeasure})
raw_data = h5py.File(raw_data_file, 'r')

# %% [markdown]
# ### 1. 전략구현

# %%
def strat(trade):
    data = trade.data
    data[''] = data.Settle.rolling(10).mean()
    data['ma60'] = data.Settle.rolling(60).mean()
    data['cross'] = (data.ma20 > data.ma60).astype('int')
    data['signal'] = data.cross.diff().shift(1)
    data.dropna(inplace=True)
    signals = data[(data.signal == 1) | (data.signal == -1)]
        
    for date, price, signal in signals[['Open','signal']].itertuples():
        if signal == 1:
            report.buy('Long', date, price)
        elif signal == -1:
            report.sell(date, price)

# %%
raw_data = h5py.File(raw_data_file, 'r')

# %%
columns = ['open','high','low','close','vol','opint','trend']
back = BackTesting(feed=raw_data, columns=columns)

# %%
back.run()
# Out:
# trading started. it takes few minutes...
# processing..(61)
# Done

# %%
back.result()
# Out:
#        cum_profit  ave_profit  cagr   mdd  win_rate  max_lose  max_profit  \
# Total   44,954.39       43.02  2.05 46.25     36.46 -4,701.00    9,489.00
#
#        ave_win  ave_lose  pl_ratio  num_trade
# Total   665.79   -314.33      0.14     108.76

# %%
data['date'] = data.index

# %%
data = back.trades[0].data[['open','close','trend']].copy()

# %%
data['signal'] = data.trend - data.trend.shift(1)

# %%
data
# Out:
#             open  close  trend  signal       date
# 2005-05-24  0.46   0.47   0.00       1 2005-05-24
# 2005-05-25  0.46   0.47   0.00       1 2005-05-25
# 2005-05-26  0.47   0.46   0.00       1 2005-05-26
# 2005-05-27  0.46   0.47   0.00       1 2005-05-27
# 2005-05-30  0.47   0.47   0.00       1 2005-05-30
# 2005-05-31  0.47   0.46   0.00       1 2005-05-31
# 2005-06-01  0.46   0.45   0.00       1 2005-06-01
# 2005-06-02  0.45   0.46   0.00       1 2005-06-02
# 2005-06-03  0.46   0.46   0.00       1 2005-06-03
# 2005-06-06  0.46   0.47   0.00       1 2005-06-06
# 2005-06-07  0.47   0.47   0.00       1 2005-06-07
# 2005-06-08  0.47   0.47   0.00       1 2005-06-08
# 2005-06-09  0.47   0.47   0.00       1 2005-06-09
# 2005-06-10  0.47   0.47   0.00       1 2005-06-10
# 2005-06-13  0.47   0.47   0.00       1 2005-06-13
# 2005-06-14  0.47   0.47   0.00       1 2005-06-14
# 2005-06-15  0.47   0.47   0.00       1 2005-06-15
# 2005-06-16  0.48   0.48   0.00       1 2005-06-16
# 2005-06-17  0.48   0.48  -1.00       2 2005-06-17
# 2005-06-20  0.48   0.48   0.00       3 2005-06-20
# 2005-06-21  0.48   0.49   0.00       3 2005-06-21
# 2005-06-22  0.48   0.48   0.00       3 2005-06-22
# 2005-06-23  0.48   0.48   0.00       3 2005-06-23
# 2005-06-24  0.48   0.47   0.00       3 2005-06-24
# 2005-06-27  0.48   0.48   0.00       3 2005-06-27
# 2005-06-28  0.48   0.47   0.00       3 2005-06-28
# 2005-06-29  0.47   0.47   0.00       3 2005-06-29
# 2005-06-30  0.47   0.47   0.00       3 2005-06-30
# 2005-07-01  0.47   0.46   0.00       3 2005-07-01
# 2005-07-04  0.46   0.46   0.00       3 2005-07-04
# ...          ...    ...    ...     ...        ...
# 2014-11-18  0.84   0.84   0.00     255 2014-11-18
# 2014-11-19  0.84   0.83   0.00     255 2014-11-19
# 2014-11-20  0.83   0.83   0.00     255 2014-11-20
# 2014-11-21  0.83   0.83   0.00     255 2014-11-21
# 2014-11-24  0.83   0.83   0.00     255 2014-11-24
# 2014-11-25  0.83   0.82   0.00     255 2014-11-25
# 2014-11-26  0.82   0.82   0.00     255 2014-11-26
# 2014-11-28  0.82   0.82   0.00     255 2014-11-28
# 2014-12-01  0.82   0.82   0.00     255 2014-12-01
# 2014-12-02  0.82   0.81   0.00     255 2014-12-02
# 2014-12-03  0.81   0.81  -1.00     256 2014-12-03
# 2014-12-04  0.81   0.81  -1.00     256 2014-12-04
# 2014-12-05  0.81   0.80  -1.00     256 2014-12-05
# 2014-12-08  0.80   0.80  -1.00     256 2014-12-08
# 2014-12-09  0.80   0.80  -1.00     256 2014-12-09
# 2014-12-10  0.80   0.80  -1.00     256 2014-12-10
# 2014-12-11  0.80   0.79  -1.00     256 2014-12-11
# 2014-12-12  0.79   0.79  -1.00     256 2014-12-12
# 2014-12-15  0.79   0.79  -1.00     256 2014-12-15
# 2014-12-16  0.79   0.79  -1.00     256 2014-12-16
# 2014-12-17  0.79   0.78  -1.00     256 2014-12-17
# 2014-12-18  0.78   0.78  -1.00     256 2014-12-18
# 2014-12-19  0.79   0.78  -1.00     256 2014-12-19
# 2014-12-22  0.78   0.78  -1.00     256 2014-12-22
# 2014-12-23  0.78   0.78  -1.00     256 2014-12-23
# 2014-12-24  0.78   0.78  -1.00     256 2014-12-24
# 2014-12-26  0.78   0.78  -1.00     256 2014-12-26
# 2014-12-29  0.78   0.78  -1.00     256 2014-12-29
# 2014-12-30  0.78   0.79  -1.00     256 2014-12-30
# 2014-12-31  0.79   0.79  -1.00     256 2014-12-31
#
# [2435 rows x 5 columns]

# %%
data.groupby('signal').filter(lambda x: x.sum() > 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-5909233f8aca> in <module>()
# ----> 1 data.groupby('signal').filter(lambda x: x.sum() > 2)
#
# C:\Python\Miniconda64\lib\site-packages\pandas\core\groupby.py in filter(self, func, dropna, *args, **kwargs)
#    3958                 raise TypeError("filter function returned a %s, "
#    3959                                 "but expected a scalar bool" %
# -> 3960                                 type(res).__name__)
#    3961
#    3962         return self._apply_filter(indices, dropna)
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %%
sf = pd.Series([1, 1, 2, 3, 3, 3])

# %%
sf.groupby(sf).filter(lambda x: x.sum() > 2)
# Out:
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
dff = pd.DataFrame({'A': np.arange(8), 'B': list('aabbbbcc')})

# %%
df.groupby('A').agg([np.sum, np.mean, np.std])
# Out:
#         C                D
#       sum  mean  std   sum  mean  std
# A
# bar  0.58  0.19 1.18 -4.31 -1.44 0.83
# foo -0.11 -0.02 0.60 -1.48 -0.30 0.60

# %%
df
# Out:
#      A      B     C     D
# 0  foo    one  0.34 -0.63
# 1  bar    one  0.83 -0.95
# 2  foo    two -0.64 -0.74
# 3  bar  three  0.92 -0.97
# 4  foo    two  0.65 -0.78
# 5  bar    two -1.17 -2.39
# 6  foo    one -0.67  0.53
# 7  foo  three  0.21  0.14
