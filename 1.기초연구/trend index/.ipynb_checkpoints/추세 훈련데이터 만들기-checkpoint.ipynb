# %%
import sys
sys.path.append('../..')
from tools import open_file
from tools import ML

# %% [markdown]
# ### 0. Parameters

# %%
raw_file = open_file('h5py', 'raw data/daily_futures.h5', mode='r')

# %%
window = 40
filepath = 'training set/trend(40day)-train.h5'

# %% [markdown]
# ### 1. Gathering Data

# %%
ML.gathering_trend(filepath, raw_file, window)
# Out:
# EUREX_FGBL
# range:  13.3421052632
# 하락(0), 기타(1), 상승(2): q

# %% [markdown]
# ### 2. Verification

# %%
from collections import Counter

# %%
file = open_file('h5py', filepath, mode='r')

# %%
print(file['X'].shape)
print(file['Y'].shape)
# Out:
# (1, 20, 4)
# (1,)

# %%
Y = file['Y']
Counter(Y)
# Out:
# Counter({1: 1})
