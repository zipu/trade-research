# %%
# %matplotlib inline
import sys
sys.path.append('../../')
from modules.tools import open_file, dataframe, ohlc_chart, norm, area_ratio, set_ATR, product_info

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter, argrelmin, argrelmax
from IPython.display import clear_output
import time

# %%
pinfo = product_info()

# %%
pdens = open_file('h5py', 'etc/historical_PD.h5', mode='r')
ohlc_raw = open_file('h5py', 'raw data/daily_futures.h5', mode='r')

# %%
tdop_db = pdens['ZW']
ohlc = dataframe('CME_W', ohlc_raw)

# %%
set_ATR(ohlc, span=20)

# %%
dates = tdop_db['dates'].value.astype('M8[D]')
tdops = tdop_db['tdop'].value
price = tdop_db['prices'].value

# %%
def split(arr, idx):
    groups = np.split(arr, np.where(np.diff(arr) != 1)[0]+1)
    args = []
    for group in groups:
        args.append(np.abs(group - idx).min())
    sortedargs = np.argsort(args)
    
    return np.array(groups)[sortedargs]

# %%
def show_graph(date):
    window = 30#int(ohlc.loc[date].ATR/pinfo['LC']['tick_unit'] ) * 1
    idx = np.where(dates==np.datetime64(date))[0][0]
    tdop = tdops[idx]
    tdop = savgol_filter(tdop, window*2+1, 3)
    tdop = norm(tdops[idx], ntype='minmax')
    
    #area_diff = area_ratio(tdop, window=window)
    #area_diff = np.where(tdop>0.2, area_diff, 0)
    area_diff = np.where(tdop>0.8, tdop, 0)
    
    fig=plt.figure(figsize=(15,9))
    ax=fig.add_subplot(111, label="ohlc")
    ax2=fig.add_subplot(111, label="tdop", frame_on=False)

    ax.yaxis.tick_right()
    start = date-np.timedelta64(360,'D')
    end = date+np.timedelta64(3,'D')
    #ax.set_xlim([date-np.timedelta64(720,'D'),date+np.timedelta64(3,'D')])
    ax = ohlc_chart(ax, ohlc.loc[start:end])
    #ax.plot(ohlc.close.loc[start:end], color='black')
    #ax.axvspan(end-np.timedelta64(40,'D'), end, color='yellow', alpha=0.5)
    
    #ax.set_ylim([1100, 2000])
    #ax.set_xlim(['2010-05-01',date+np.timedelta64(3,'D')])
    #ax2.plot(area_diff, price, color="red", alpha=1, linewidth=0.8)
    ax2.fill_betweenx(price, 0,np.where(area_diff>0.7, 1, 0), color="red", alpha=0.4)
    ax2.fill_betweenx(price, 0,np.where(area_diff<-0.7, 1, 0), color="blue", alpha=0.4)
    #ax2.plot(np.where(area_diff<-0.5, 1, 0), price, color="blue", alpha=1, linewidth=0.8)
    ax2.set_ylim(ax.get_ylim())
    ax2.xaxis.tick_top()
    ax2.set_xlim([0, 1])
    
    plt.show()

# %%
for date in ohlc.index[2200::1]:
    #print(date)
    show_graph(date)
    time.sleep(1)
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-82380e831d62> in <module>()
#       1 for date in ohlc.index[2200::1]:
#       2     #print(date)
# ----> 3     show_graph(date)
#       4     #s=input('enter')
#       5     #if s == 'q':
#
# NameError: name 'show_graph' is not defined

# %%
pd.Series(tdop).rolling(200).mean().plot()

# %%
from functools import reduce
for date in ohlc.index[200::5]:
    window = int(ohlc.loc[date].ATR/pinfo['ZW']['tick_unit'] ) * 2
    idx = np.argmax(dates==np.datetime64(date))
    pidx = np.argmax(price == ohlc.loc[date].close)
    tdop = tdops[idx]
    tdop = savgol_filter(tdop, 101, 3)
    #tdop = pd.Series(tdop).rolling(window).mean().values
    tdop = norm(tdop, ntype='minmax')
    
    th = np.where(tdop>0.7)[0]
    
    arridx = split(th, pidx)
    
    #ratio_cut = np.where(tdop>0.5, ratio, 0)
    plt.figure().set_size_inches(10,8)
    plt.axes().axvline(ohlc.loc[date].close, color='black')
    plt.plot(price, tdop)
    
    plt.scatter(price[arridx[0]],tdop[arridx[0]], color='red', s=5)
    if len(arridx) > 1:
        plt.scatter(price[arridx[1]],tdop[arridx[1]], color='C1', s=5)
    plt.show()
    time.sleep(0.5)
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-453-4723d3233500> in <module>()
#      21     if len(arridx) > 1:
#      22         plt.scatter(price[arridx[1]],tdop[arridx[1]], color='C1', s=5)
# ---> 23     plt.show()
#      24     time.sleep(0.5)
#      25     clear_output(wait=True)
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# C:\Python\Miniconda64\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     300             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     301         else:
# --> 302             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     303             if not format_dict:
#     304                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     169             md = None
#     170             try:
# --> 171                 data = formatter(obj)
#     172             except:
#     173                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     213     """show traceback on failed format call"""
#     214     try:
# --> 215         r = method(self, *args, **kwargs)
#     216     except NotImplementedError:
#     217         # don't warn on NotImplementedErrors
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python\Miniconda64\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     119
#     120     bytes_io = BytesIO()
# --> 121     fig.canvas.print_figure(bytes_io, **kw)
#     122     data = bytes_io.getvalue()
#     123     if fmt == 'svg':
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in _update_ticks(self, renderer)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in iter_ticks(self)
#     911         """
#     912         majorLocs = self.major.locator()
# --> 913         majorTicks = self.get_major_ticks(len(majorLocs))
#     914         self.major.formatter.set_locs(majorLocs)
#     915         majorLabels = [self.major.formatter(val, i)
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1331                 if self._gridOnMajor:
#    1332                     tick.gridOn = True
# -> 1333                 self._copy_tick_props(protoTick, tick)
#    1334
#    1335         self._lastNumMajorTicks = numticks
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1286         dest.label2.update_from(src.label2)
#    1287
# -> 1288         dest.tick1line.update_from(src.tick1line)
#    1289         dest.tick2line.update_from(src.tick2line)
#    1290         dest.gridline.update_from(src.gridline)
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1330         self._linestyle = other._linestyle
#    1331         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1332                                    other._marker.get_fillstyle())
#    1333         self._drawstyle = other._drawstyle
#    1334
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\markers.py in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     720
#     721     def _set_tickdown(self):
# --> 722         self._transform = Affine2D().scale(1.0, -1.0)
#     723         self._snap_threshold = 1.0
#     724         self._filled = False
#
# C:\Python\Miniconda64\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
#    1987             np.float_)
# -> 1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#    1990         return self
#
# KeyboardInterrupt:

# %%
len(arridx)
# Out:
# 1

# %%
pidx = np.argmax(price == ohlc.loc[date].close)

# %%
th[np.abs(pidx - th).argmin()]
# Out:
# 6113

# %%
tdop = tdops[1000]
tdop = norm(tdop, ntype='minmax')
tdop = savgol_filter(tdop, 101, 3)

# %%
plt.plot(tdop)

# %%
maxs = []
mins = []
for date in ohlc.index:
    print(f"\r {date}   ", flush=True, end='')
    window = int(ohlc.loc[date].ATR/pinfo['ZW']['tick_unit'] )
    close = ohlc.loc[date].close
    pidx = np.argmax(price==close)
    idx = np.argmax(dates==np.datetime64(date))
    
    tdop = tdops[idx]
    tdop = savgol_filter(tdop, window*2+1, 3)
    tdop = norm(tdop, ntype='minmax')
    
    th = np.where(tdop>0.5)[0]
    arridx = split(th, pidx)[0]
    maxs.append(price[arridx.max()])
    mins.append(price[arridx.min()])
# Out:
#  2014-12-31 00:00:00

# %%
plt.plot(maxs)
plt.plot(mins)

# %%
data = ohlc[:]
fig=plt.figure(figsize=(15,9))
ax=fig.add_subplot(111, label="ohlc")
ax = ohlc_chart(ax, data)
ax.plot(data.index, mins)
ax.plot(data.index, maxs)
#ax.set_xlim(['2006-01-01','2008-06-01'])
#ax.set_ylim([0.4,0.75])

# %%
len(mins)
# Out:
# 300

# %%
p = np.argwhere(price == ohlc.loc[date].close)[0][0]

# %%
maxidx[np.abs(p-maxidx).argsort()[0]]
# Out:
# 7554

# %%
np.intersect1d(maxidx, s)
# Out:
# array([ 317,  596,  983, 1725, 2290], dtype=int64)

# %%
maxidx
# Out:
# array([ 317,  596,  983, 1530, 1725, 1932, 2290], dtype=int64)

# %%
ratio[mask]=0

# %%
plt.plot(ratio)

# %%
plt.plot(price,area_diff)

# %%
plt.plot(price,tdop)

# %%
plt.plot(ohlc.close)

# %%
window = 50
lmaxs = []

for date in ohlc.index[:200]:
    print(f'\r {date}  ', flush=True, end='')
    
    idx = np.where(dates == np.datetime64(date))[0][0]
    closeprice = ohlc.loc[date].close
    closeidx = np.where(price == closeprice)[0][0]
    
    tdop = tdops[idx]
    smoothed = savgol_filter(tdop, window*2+1, 3)
    
    localmax = argrelmax(smoothed, order=window)[0]
    #localmax = localmax[localmax <= closeidx]
    localmax = localmax[np.abs(localmax - closeidx).argsort()[-5:]]
    
    lmax = price[localmax]
    lmax = np.append(lmax, np.full(7-len(lmax), np.nan))
    
    lmaxs.append(lmax)

lmaxs = np.array(lmaxs)
# Out:
#  2014-12-31 00:00:00

# %%
diff = area_ratio(arr, window=25)

# %%
plt.plot(arr)

# %%
arr
# Out:
# array([ 0.01008529,  0.01008529,  0.01008529, ...,  0.        ,
#         0.        ,  0.        ])

# %%
tdop.shape
# Out:
# (13734,)

# %%
lmaxs = lmax

# %%
test
# Out:
# array([array([ 636.3]), array([ 632.5]), array([ 632.3])], dtype=object)

# %%
ohlc.index.shape
# Out:
# (2516,)

# %%
np.empty(3)
# Out:
# array([ 1.,  2.,  3.])

# %%
np.array([np.nan])+ np.array([1,2,3])
# Out:
# array([ nan,  nan,  nan])

# %%
x = np.array( [np.full(5, i) for i in range(10) ] )
for i in range(10):
    plt.scatter(np.full(len(lmax[i]), i),lmax[i])

# %%
lmax[0].shape
# Out:
# (1,)

# %%
lmax.shape
# Out:
# (10, 5)

# %%
closeprice
# Out:
# 618.60000000000002

# %%
s=np.abs(price[localmax] - closeprice).argsort()

# %%
np.where(price == closeprice)[0][0]
# Out:
# 57

# %%
localmax
# Out:
# (array([ 56, 150], dtype=int64),)

# %%
price.shape
# Out:
# (13734,)

# %%
diff.shape
# Out:
# (13734,)

# %%
diff = area_ratio(arr, window=window)
localmaxs = argrelmax(diff, order=window)[0]

# %%
localmaxs
# Out:
# array([ 171,  257,  326,  576,  684,  767,  849,  937, 1071, 1249, 1395,
#        1472, 1759, 1887, 1984, 2072, 2241, 2517, 2594, 2796, 3080, 3194,
#        3421, 3709, 3843, 3969, 4120, 4270, 4351, 4489, 4666, 4788, 4891,
#        5161, 5340, 5465, 5604, 5752, 5922, 6065, 6216, 6354, 6528, 6791,
#        7132, 7233], dtype=int64)

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(price, diff)
ax.scatter(price[localmaxs], diff[localmaxs])
ax.set_xlim([800,1000])
#plt.scatter(localmax, smoothed[localmax], color='red')
# Out:
# (800, 1000)

# %%
plt.plot(arr)

# %%
set_ATR(ohlc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-58dad71663e1> in <module>()
# ----> 1 set_ATR(ohlc)
#
# ~\Documents\projects\research\modules\tools\factory.py in set_ATR(metrics, span)
#     116     """
#     117
# --> 118     df = pd.DataFrame()
#     119     df['hl'] = metrics['high'] - metrics['low']
#     120     df['hc'] = np.abs(metrics['high'] - metrics['close'].shift(1))
#
# NameError: name 'pd' is not defined

# %%
def autoscale_y(ax,margin=0.1):
    """This function rescales the y-axis based on the data that is visible given the current xlim of the axis.
    ax -- a matplotlib axes object
    margin -- the fraction of the total height of the y-data to pad the upper and lower ylims"""


    def get_bottom_top(line):
        xd = line.get_xdata()
        yd = line.get_ydata()
        lo,hi = ax.get_xlim()
        y_displayed = yd[((xd>lo) & (xd<hi))]
        h = np.max(y_displayed) - np.min(y_displayed)
        bot = np.min(y_displayed)-margin*h
        top = np.max(y_displayed)+margin*h
        return bot,top

    lines = ax.get_lines()
    bot,top = np.inf, -np.inf

    for line in lines:
        new_bot, new_top = get_bottom_top(line)
        if new_bot < bot: bot = new_bot
        if new_top > top: top = new_top

    ax.set_ylim(bot,top)
