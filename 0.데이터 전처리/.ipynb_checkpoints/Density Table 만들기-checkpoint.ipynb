# %%
# %matplotlib inline
import sys
sys.path.append('../')
import tables as tb
import h5py
import numpy as np
import pandas as pd
from datetime import datetime
import scipy.sparse as sp
import matplotlib.pyplot as plt
import sqlite3 as lite
from modules.tools import DateMapper, Minute, Density
from modules.tools import open_file, product_info

# %% [markdown]
# ### 일별 OHLC 변환하여 TDOP (Trade Density On Price) 만들기

# %%
filters = tb.Filters(complib='blosc', complevel=9)
raw_data = open_file('h5py', 'raw data/daily_futures.h5', mode='r')

# %%
tdop = tb.open_file('../data/etc/tdops2.hdf5', mode='a', filters=filters)

# %%
#종목정보 불러오기
pinfo = product_info()

# %%
for cnt, file in enumerate(raw_data.values()):
    #if cnt == 1:
    #    break
    
    symbol = file.attrs['symbol']
    name = file.attrs['name']
    source = file.value[:,[0,2,3,5]] #date,high,low,volume
    
    if symbol == 'None':
        continue
    
    print('\r %s (%s/%s)'%(name,cnt,len(raw_data)), end='', flush=True)

    #pytables cursor
    group = tdop.create_group('/', symbol, name)
    #datemapper = tdob.create_table(group, 'DateMapper', DateMapper)
    #minute = tdob.create_table(group, 'Minute', Minute)
    density = tdop.create_table(group, 'Density', Density)
    
    data = []
    #환경변수
    tick_unit = pinfo[symbol]['tick_unit']
    digit = pinfo[symbol]['decimal_places']
    
    #pandas dataframe
    #df = pd.DataFrame(group.Daily.read()).sort_values('date', ascending=True)
    
    for date, high, low, volume in source:
        
        if round(low, digit) == round(high, digit):
            #continue #일봉에서 고가 == 저가 이면 문제 있는 데이터임. 버림.
            data.append((date, round(low, digit), volume))
        
        else:
            length = (high - low)/tick_unit + 1
            length = np.rint(length)
            value = volume/length
            
            if np.isinf(value) or (value < 0.1): #inf 또는 틱탕 너무 작은 value 버림
                #print("wrong volume", row.volume, length, name, str(row.date.astype('M8[s]').astype('M8[D]')))
                continue
            else:
                for price in np.arange(round(low, digit), high-tick_unit/2, tick_unit):
                    data.append((date, price, value))
    if data:
        density.append(data)
        density.flush()
print("\nEverythin fin.")
# Out:
#  ICE Russell 2000 Index Mini (63/77)7)
# Everythin fin.

# %%
tdop.close()

# %% [markdown]
# ### Verification

# %%
# 중복데이터 체크
from collections import Counter

for grp in tdop.iter_nodes('/'):
    item = grp.Density.cols.date[:]
    dup = [item for item, count in Counter(item).items() if count > 1]
    if dup:
        print(grp._v_title, " has duplicated data")
print('done')
# Out:
# CME Australian Dollar AUD  has duplicated data
# CME British Pound GBP  has duplicated data
# ICE Cocoa  has duplicated data
# CME Canadian Dollar CAD  has duplicated data
# NYMEX WTI Crude Oil  has duplicated data
# ICE Cotton  has duplicated data
# ICE US Dollar Index  has duplicated data
# CME Eurodollar  has duplicated data
# CME S&P 500 Index E-Mini  has duplicated data
# EUREX Euro-BTP  has duplicated data
# EUREX DAX  has duplicated data
# EUREX EURO STOXX 50 Index  has duplicated data
# EUREX Euro-Bund  has duplicated data
# EUREX Euro-Bobl  has duplicated data
# EUREX Euro-Schatz  has duplicated data
# NYMEX Gold  has duplicated data
# COMEX Copper  has duplicated data
# NYMEX Heating Oil  has duplicated data
# CME Japanese Yen JPY  has duplicated data
# ICE Coffee C  has duplicated data
# CME Live Cattle  has duplicated data
# ICE Brent Crude Oil  has duplicated data
# ICE Gasoil  has duplicated data
# CME Lean Hogs  has duplicated data
# CME New Zealand Dollar NZD  has duplicated data
# NYMEX Natural Gas  has duplicated data
# CME Nikkei 225  has duplicated data
# CME NASDAQ 100 Index Mini  has duplicated data
# ICE Orange Juice  has duplicated data
# NYMEX Palladium  has duplicated data
# NYMEX Platinum  has duplicated data
# ICE Sugar No. 11  has duplicated data
# CME Swiss Franc CHF  has duplicated data
# NYMEX Silver  has duplicated data
# ICE Russell 2000 Index Mini  has duplicated data
# CME Euro FX  has duplicated data
# ICE WTI Crude Oil  has duplicated data
# CME E-mini Dow Jones  has duplicated data
# CBOT 30-year US Treasury Bond  has duplicated data
# CBOT Corn  has duplicated data
# CBOT 5-year US Treasury Note  has duplicated data
# CBOT Soybean Oil  has duplicated data
# CBOT Soybean Meal  has duplicated data
# CBOT 10-year US Treasury Note  has duplicated data
# CBOT Oats  has duplicated data
# CBOT Rough Rice  has duplicated data
# CBOT Soybeans  has duplicated data
# CBOT 2-year US Treasury Note  has duplicated data
# CBOT Wheat  has duplicated data
# done

# %%
tdop.close()

# %%
data = raw_data['CME_AD'].value

# %%
plt.plot(data[:,1])
